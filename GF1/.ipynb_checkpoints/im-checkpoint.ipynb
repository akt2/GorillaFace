# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=20, n_features=1, random_state=0, noise=4, bias=100.0)

# %%
plt.scatter(X,y)

# %%
import skimage as sk
import os
from skimage import data,filters,io,exposure,feature
import numpy as np
import IPython
import PIL
import recognize
import pyimagesearch.localbinarypatterns
from imutils import paths

# %%
file=os.path.join('C:/','Desktop/','Dunia.png')
file2=os.path.join('C:/','Documents/','Data Analytics/','New Folder/','TUY.png')

# %%
dun=io.imread('Dunia.png')
tuy=io.imread('TUY.jpg')

# %%
dun.shape
# tuy.shape
# Out:
# (1122, 1498, 4)

# %%
plt.figure(figsize=(15,15))
plt.imshow(tuy)

# %%
stretcht=exposure.rescale_intensity(tuy)
stretchd=exposure.rescale_intensity(dun)

# %%
plt.imshow(stretchd)

# %%
greyt = sk.color.rgb2gray(stretcht) * 255
greyd = skimage.color.rgb2gray(stretchd) * 255
IPython.display.display(PIL.Image.fromarray(greyd).convert('RGB'))
# Out:
# <PIL.Image.Image image mode=RGB size=1498x1122 at 0x217DD06E978>

# %%
for imagePath in paths.list_images(os.path.join(bob['training'])):
    image = io.imread(imagePath)
    stretch = exposure.rescale_intensity(image)
    grey = sk.color.rgb2gray(stretch)
    hist = desc.describe(grey)
    labels.append(imagePath.split(os.path.sep)[-2])
    data.append(hist)
    
model = LinearSVC(C=100.0, random_state=42)
model.fit(data, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0addfd04723d> in <module>
#       7     data.append(hist)
#       8
# ----> 9 model = LinearSVC(C=100.0, random_state=42)
#      10 model.fit(data, labels)
#
# NameError: name 'LinearSVC' is not defined
